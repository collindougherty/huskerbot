# %%
# let's build a twitter bot that retweets tweets with a specific hashtag

import tweepy
import time

# Authenticate to Twitter
auth = tweepy.OAuthHandler("n7oLL24FhGfhn2EFAGaLHa3FU", "hmD3sdkOQ0IxL4IHudYrpVXBhA0ywHR8ri02E0C9WI7NFfFmJX")
auth.set_access_token("1570614022277402624-1uO6DpXpsAbdC5ktyls4HGJi1opwt8", "jTwA1gbXktLZLYHH4XbEQ9OfpUXBjOraojTFi4YatubN6")

# Create API object
api = tweepy.API(auth, wait_on_rate_limit=True,
    wait_on_rate_limit_notify=True)

# Create a tweet
# api.update_status("Hello Tweepy")

# Create a user object
user = api.me()
print(user.name)

# # Print out details
# print(user.screen_name)
# print(user.followers_count)
# for friend in user.friends():
#     print(friend.screen_name)

# # Limiting the amount of tweets
# for tweet in tweepy.Cursor(api.home_timeline).items(5):
#     print(f"{tweet.user.name} said {tweet.text}")

# # Search for tweets
# search = "Python"
# numberOfTweets = 2

# for tweet in tweepy.Cursor(api.search, search).items(numberOfTweets):
#     try:
#         tweet.favorite()
#         print("I liked that tweet")
#     except tweepy.TweepError as e:
#         print(e.reason)
#     except StopIteration:
#         break

# # Retweet tweets with a specific hashtag
# search = "#100DaysOfCode"
# numberOfTweets = 5

# for tweet in tweepy.Cursor(api.search, search).items(numberOfTweets):
#     try:
#         tweet.retweet()
#         print("I liked that tweet")
#     except tweepy.TweepError as e:
#         print(e.reason)
#     except StopIteration:
#         break

# # Follow back followers
# for follower in tweepy.Cursor(api.followers).items():
#     follower.follow()
#     print("Followed everyone that is following " + user.name)

# # Create a list of followers
# followers = []
# for follower in tweepy.Cursor(api.followers).items():
#     followers.append(follower)

# # Print out the list of followers
# print(followers)

# # Print out the list of followers
# for follower in followers:
#     print(follower.name)
